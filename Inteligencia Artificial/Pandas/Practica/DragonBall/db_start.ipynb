# %%
import pandas as pd
db = pd.read_csv("Dragon_Ball_Data_Set.csv")
db
# Out:
#                              Character            Power_Level  \
# 0                                 Goku                     10
# 1                                Bulma                    1.5
# 2                           Bear Thief                      7
# 3                         Master Roshi                     30
# 4                               Oolong                      5
# ...                                ...                    ...
# 1239     Goku (MSSJ with SSJG's power)     22,400,000,000,000
# 1240                       Goku (SSJG)    224,000,000,000,000
# 1241                              Goku         44,800,000,000
# 1242  Beerus (full power, never shown)    896,000,000,000,000
# 1243    Whis (full power, never shown)  4,480,000,000,000,000
#
#                  Saga_or_Movie Dragon_Ball_Series
# 0           Emperor Pilaf Saga        Dragon Ball
# 1           Emperor Pilaf Saga        Dragon Ball
# 2           Emperor Pilaf Saga        Dragon Ball
# ...

# %%
db.head(20 + 1) # The first 20 rows

db.tail(5) # The last 5
# Out:
#                              Character            Power_Level  \
# 1239     Goku (MSSJ with SSJG's power)     22,400,000,000,000
# 1240                       Goku (SSJG)    224,000,000,000,000
# 1241                              Goku         44,800,000,000
# 1242  Beerus (full power, never shown)    896,000,000,000,000
# 1243    Whis (full power, never shown)  4,480,000,000,000,000
#
#                  Saga_or_Movie Dragon_Ball_Series
# 1239  Movie 14: Battle of Gods      Dragon Ball Z
# 1240  Movie 14: Battle of Gods      Dragon Ball Z
# 1241  Movie 14: Battle of Gods      Dragon Ball Z
# 1242  Movie 14: Battle of Gods      Dragon Ball Z
# 1243  Movie 14: Battle of Gods      Dragon Ball Z

# %%
print(db.columns) # return all of the columns

print(db["Character"])  # read an specific column
print(db[["Character", "Power_Level"]])  # read  specific column but we need to put [[]] when we have more than 1 column to read
# Out:
# Index(['Character', 'Power_Level', 'Saga_or_Movie', 'Dragon_Ball_Series'], dtype='object')
# 0                                   Goku
# 1                                  Bulma
# 2                             Bear Thief
# 3                           Master Roshi
# 4                                 Oolong
#                       ...
# 1239       Goku (MSSJ with SSJG's power)
# 1240                         Goku (SSJG)
# 1241                                Goku
# 1242    Beerus (full power, never shown)
# 1243      Whis (full power, never shown)
# Name: Character, Length: 1244, dtype: object
#                              Character            Power_Level
# 0                                 Goku                     10
# 1                                Bulma                    1.5
# 2                           Bear Thief                      7
# 3                         Master Roshi                     30
# 4                               Oolong                      5
# ...

# %%
print(db.iloc[1243,0]) # Return a specific row
# Out:
# Whis (full power, never shown)

# %%
print(db.iloc[1243, 0]) # This is the stronger character
# Out:
# Whis (full power, never shown)

# %%
for index, row in db.iterrows(): 
  print(index, row["Saga_or_Movie"])
  print(db.head(99))
# Out:
# 0 Emperor Pilaf Saga
#                   Character Power_Level       Saga_or_Movie Dragon_Ball_Series
# 0                      Goku          10  Emperor Pilaf Saga        Dragon Ball
# 1                     Bulma         1.5  Emperor Pilaf Saga        Dragon Ball
# 2                Bear Thief           7  Emperor Pilaf Saga        Dragon Ball
# 3              Master Roshi          30  Emperor Pilaf Saga        Dragon Ball
# 4                    Oolong           5  Emperor Pilaf Saga        Dragon Ball
# ..                      ...         ...                 ...                ...
# 94  King Piccolo (weakened)         230   King Piccolo Saga        Dragon Ball
# 95          Goku (weakened)         225   King Piccolo Saga        Dragon Ball
# 96        Goku's Penetrate!         320   King Piccolo Saga        Dragon Ball
# 97                   Yamcha         126   King Piccolo Saga        Dragon Ball
# 98                  Krillin         130   King Piccolo Saga        Dragon Ball
#
# ...

# %%
print(len(db.loc[db["Character"]=="Oolong"]))
# Out:
# 1

# %%
print(db.describe)
# Out:
# <bound method NDFrame.describe of                              Character            Power_Level  \
# 0                                 Goku                     10
# 1                                Bulma                    1.5
# 2                           Bear Thief                      7
# 3                         Master Roshi                     30
# 4                               Oolong                      5
# ...                                ...                    ...
# 1239     Goku (MSSJ with SSJG's power)     22,400,000,000,000
# 1240                       Goku (SSJG)    224,000,000,000,000
# 1241                              Goku         44,800,000,000
# 1242  Beerus (full power, never shown)    896,000,000,000,000
# 1243    Whis (full power, never shown)  4,480,000,000,000,000
#
#                  Saga_or_Movie Dragon_Ball_Series
# 0           Emperor Pilaf Saga        Dragon Ball
# 1           Emperor Pilaf Saga        Dragon Ball
# ...

# %%
print(db.sort_values("Power_Level"))
# Out:
#             Character                  Power_Level  \
# 1125       Android 18  (supressed, figting Trunks)
# 118             Gohan                            1
# 1139             Puck                            1
# 776             Gohan                            1
# 844     Slug Soldiers                        1,000
# ...               ...                          ...
# 481      Goten (MSSJ)                  980,000,000
# 75    Tien's Tri Beam                          985
# 473     Gotenks (SSJ)                   99,000,000
# 1052    Gotenks (SSJ)               99,000,000,000
# 589          Don Para                    6,800,000
#
#                          Saga_or_Movie Dragon_Ball_Series
# 1125  Dragon Ball Z: History of Trunks      Dragon Ball Z
# 118                        Saiyan Saga      Dragon Ball Z
# 1139   Dragon Ball GT: A Hero's Legacy      Dragon Ball Z
# 776                 Movie 1: Dead Zone      Dragon Ball Z
# ...
